# %%
# !pip -q install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.98 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# Setup complete ✅ (48 CPUs, 125.7 GB RAM, 185.1/200.3 GB disk)

# %%
# !pwd
# Out:
# /bin/bash: /home/planck/anaconda3/envs/bikash/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /DATA1/bikash_dutta/DL/Project/YOLO

# %%
	
# !yolo task=detect mode=train model=yolov8n.pt imgsz=640 data="./train_data/bird_dataset_custom.yml" epochs=100 batch=10 name=yolov8n_cutom_dataset_bird
# Out:
# /bin/bash: /home/planck/anaconda3/envs/bikash/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Ultralytics YOLOv8.0.98 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# ...

# %%
# !yolo train model=yolov8n.pt data="/content/table_data/Table_data.yaml" epochs=50 imgsz=640 batch=10

# %%
# import torch
# import cv2
# import torchvision.transforms as transforms
# from google.colab.patches import cv2_imshow
# # Load the trained YOLOv5 model
# # model = torch.hub.load('ultralytics/yolov5', 'custom', path='path/to/trained/model.pt')
# #model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
        
# # model = torch.hub.load('/content/','custom', path='yolov8n.pt',force_reload=True,source='local', pretrained =False)
# # Load the test image|
# img = cv2.imread("/content/cv_input.jpg")

# # Transform the image to the required format
# transform = transforms.Compose([
#     transforms.Resize(640),
#     transforms.ToTensor(),
# ])
# cv2_imshow(img)

# %%
# !yolo detect predict model=runs/detect/yolov8n_cutom_dataset_bird2/weights/best.pt source="./examples_vid/vid4.mp4" save=True
# Out:
# /bin/bash: /home/planck/anaconda3/envs/bikash/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 2023-05-12 10:23:09.868570: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.98 🚀 Python-3.10.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3090, 24257MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/6390) /DATA1/bikash_dutta/DL/Project/YOLO/examples_vid/vid4.mp4: 384x640 (no detections), 60.8ms
# video 1/1 (2/6390) /DATA1/bikash_dutta/DL/Project/YOLO/examples_vid/vid4.mp4: 384x640 (no detections), 5.3ms
# video 1/1 (3/6390) /DATA1/bikash_dutta/DL/Project/YOLO/examples_vid/vid4.mp4: 384x640 (no detections), 5.0ms
# video 1/1 (4/6390) /DATA1/bikash_dutta/DL/Project/YOLO/examples_vid/vid4.mp4: 384x640 (no detections), 5.0ms
# ...

# %%
# !yolo detect predict model = yolov8n.pt source = "/content/word_database_documentation.png"

# %%
# # Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='/content/cv_input.jpg'
